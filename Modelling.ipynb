# %%
import pandas as pd
from xgboost import XGBRegressor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-3e092ad6f08f> in <module>
#       1 import pandas as pd
# ----> 2 from xgboost import XGBRegressor
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
# !pip install xgboost
# Out:
# ...
#   ERROR: Command errored out with exit status 1:
#    command: 'c:\users\marcus-desktop\appdata\local\programs\python\python38-32\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Marcus-desktop\\AppData\\Local\\Temp\\pip-install-lb3m5tow\\xgboost\\setup.py'"'"'; __file__='"'"'C:\\Users\\Marcus-desktop\\AppData\\Local\\Temp\\pip-install-lb3m5tow\\xgboost\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\Marcus-desktop\AppData\Local\Temp\pip-wheel-se0jq7x4'
#        cwd: C:\Users\Marcus-desktop\AppData\Local\Temp\pip-install-lb3m5tow\xgboost\
#   Complete output (1051 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win32-3.8
#   creating build\lib.win32-3.8\xgboost
#   copying xgboost\callback.py -> build\lib.win32-3.8\xgboost
# ...

# %%
df = pd.read_csv('data/wrangled_data2.csv')
df
# Out:
#                  Street   Area  Dorms  Baths  Parking Slots  Condominio  \
# 0       Barão de Icaraí  160.0      2      3              2      1200.0
# 1       Barão de Icaraí  100.0      2      1              2       950.0
# 2       Barão de Icaraí   78.0      2      2              1       790.0
# 3       Barão de Icaraí  102.0      3      2              1      1100.0
# 4       Barão de Icaraí  130.0      3      2              1      1650.0
# ...                 ...    ...    ...    ...            ...         ...
# 1750  Senador Vergueiro  385.0      5      3              1      3680.0
# 1751  Senador Vergueiro  385.0      5      3              1      3680.0
# 1752  Senador Vergueiro  198.0      4      4              1      1600.0
# 1753  Senador Vergueiro  160.0      3      3              1      1500.0
# 1754  Senador Vergueiro  220.0      4      3              1      1555.0
#
#          IPTU      Price
# 0       433.0  1800000.0
# 1       280.0  1050000.0
# ...
